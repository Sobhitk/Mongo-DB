# %% [markdown]
# # THEORETICAL QUESTIONS
# 1. What are the key differences between SQL and NoSQL databases?
#
# >>SQL databases are relational, schema-based, and store data in tables, whereas NoSQL databases are non-relational, schema-flexible, and store data in formats like documents, key-value pairs, or graphs. SQL supports complex joins and vertical scaling, while NoSQL supports horizontal scaling and is better for big data and distributed systems.
#
# 2. What makes MongoDB a good choice for modern applications?
#
# >>MongoDB offers schema flexibility, high scalability, fast read/write operations, horizontal scaling, and easy integration with cloud and microservices, making it ideal for modern applications.
#
# 3. Explain the concept of collections in MongoDB.
#
# >>A collection in MongoDB is a group of documents stored together. It is similar to a table in SQL but does not enforce a fixed schema, allowing documents with different structures.
#
# 4. How does MongoDB ensure high availability using replication?
#
# >>MongoDB uses replica sets, where data is copied across multiple nodes. One node acts as the primary and others as secondary. If the primary fails, a secondary automatically becomes the new primary.
#
# 5. What are the main benefits of MongoDB Atlas?
#
# >>MongoDB Atlas provides a fully managed cloud database with automatic backups, scaling, monitoring, security, and global deployment support.
#
# 6. What is the role of indexes in MongoDB, and how do they improve performance?
#
# >>Indexes allow MongoDB to locate documents quickly without scanning the entire collection, significantly improving query performance.
#
# 7. Describe the stages of the MongoDB aggregation pipeline.
#
# >>Common aggregation stages include:
# $match – filter documents
# $group – group data
# $sort – sort results
# $project – reshape output
# $lookup – join collections
#
# 8. What is sharding in MongoDB? How does it differ from replication?
#
# >>Sharding distributes data across multiple servers for scalability, while replication copies data across servers for availability and fault tolerance.
#
# 9. What is PyMongo, and why is it used?
#
# >>PyMongo is the official Python driver for MongoDB. It allows Python applications to connect, query, and manipulate MongoDB databases.
#
# 10. What are the ACID properties in MongoDB transactions?
#
# >>ACID stands for Atomicity, Consistency, Isolation, and Durability. MongoDB supports ACID properties in multi-document transactions.
#
# 11. What is the purpose of MongoDB’s explain() function?
#
# >>The explain() function shows how a query is executed, including index usage and execution time, helping in performance optimization.
#
# 12. How does MongoDB handle schema validation?
#
# >>MongoDB uses JSON Schema validation to enforce rules on documents, such as required fields and data types.
#
# 13. What is the difference between a primary and a secondary node in a replica set?
#
# >>The primary node handles all write operations, while secondary nodes replicate data from the primary and can serve read requests.
#
# 14. What security mechanisms does MongoDB provide for data protection?
#
# >>MongoDB provides authentication, role-based access control, encryption at rest and in transit, auditing, and network security.
#
# 15. Explain embedded documents and when they should be used.
#
# >>Embedded documents store related data within a single document. They should be used when data is frequently accessed together.
#
# 16. What is the purpose of MongoDB’s $lookup stage?
#
# >>The $lookup stage performs a left outer join between collections in aggregation pipelines.
#
# 17. What are some common use cases for MongoDB?
#
# >>Common use cases include e-commerce, real-time analytics, IoT applications, content management systems, and mobile apps.
#
# 18. What are the advantages of using MongoDB for horizontal scaling?
#
# >>MongoDB supports automatic sharding, load balancing, and distributed data storage, making horizontal scaling efficient.
#
# 19. How do MongoDB transactions differ from SQL transactions?
#
# >>MongoDB transactions are designed for distributed systems and scalability, whereas SQL transactions are tightly coupled with relational schemas.
#
# 20. What are the differences between capped collections and regular collections?
#
# >>Capped collections have a fixed size and automatically overwrite old data, while regular collections grow dynamically.
#
# 21. What is the purpose of the $match stage in aggregation?
#
# >>$match filters documents early in the pipeline, improving performance by reducing the data processed.
#
# 22. How can you secure access to a MongoDB database?
#
# >>By enabling authentication, using strong passwords, role-based access control, IP whitelisting, and encryption.
#
# 23. What is MongoDB’s WiredTiger storage engine and why is it important?
#
# >>WiredTiger is MongoDB’s default storage engine, providing high performance, compression, and concurrency control.

# %%
# PRACTICAL
#1. Write a Python script to load the Superstore dataset into MongoDB.
import pandas as pd
from pymongo import MongoClient

df = pd.read_csv("mongo DB assim.csv", encoding="latin1")

client = MongoClient("mongodb://localhost:27017/")
db = client["superstoreDB"]
db.orders.insert_many(df.to_dict("records"))

print("Data inserted successfully into MongoDB")
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /tmp/ipython-input-3165339419.py in <cell line: 0>()
#       8 client = MongoClient("mongodb://localhost:27017/")
#       9 db = client["superstoreDB"]
# ---> 10 db.orders.insert_many(df.to_dict("records"))
#      11
#      12 print("Data inserted successfully into MongoDB")
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973         blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974         blk.ops = list(gen())
# --> 975         blk.execute(write_concern, session, _Op.INSERT)
#     976         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     977
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/bulk.py in execute(self, write_concern, session, operation)
#     749                 return None
#     750         else:
# --> 751             return self.execute_command(generator, write_concern, session, operation)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/bulk.py in execute_command(self, generator, write_concern, session, operation)
#     602
#     603         client = self.collection.database.client
# --> 604         _ = client._retryable_write(
#     605             self.is_retryable,
#     606             retryable_bulk,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2080         """
#    2081         with self._tmp_session(session) as s:
# -> 2082             return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#    2083
#    2084     def _cleanup_cursor_no_lock(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1966             retryable and self.options.retry_writes and session and not session.in_transaction
#    1967         )
# -> 1968         return self._retry_internal(
#    1969             func=func,
#    1970             session=session,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    2012             retryable=retryable,
#    2013             operation_id=operation_id,
# -> 2014         ).run()
#    2015
#    2016     def _retryable_read(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in run(self)
#    2763             self._check_last_error(check_csot=True)
#    2764             try:
# -> 2765                 return self._read() if self._is_read else self._write()
#    2766             except ServerSelectionTimeoutError:
#    2767                 # The application may think the write was never attempted
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _write(self)
#    2873             max_wire_version = 0
#    2874             is_mongos = False
# -> 2875             self._server = self._get_server()
#    2876             with self._client._checkout(self._server, self._session) as conn:
#    2877                 max_wire_version = conn.max_wire_version
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _get_server(self)
#    2856         :return: Abstraction to connect to server
#    2857         """
# -> 2858         return self._client._select_server(
#    2859             self._server_selector,
#    2860             self._session,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831                     raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832             else:
# -> 1833                 server = topology.select_server(
#    1834                     server_selector,
#    1835                     operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     407     ) -> Server:
#     408         """Like select_servers, but choose a random server if several match."""
# --> 409         server = self._select_server(
#     410             selector,
#     411             operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     385         operation_id: Optional[int] = None,
#     386     ) -> Server:
# --> 387         servers = self.select_servers(
#     388             selector, operation, server_selection_timeout, address, operation_id
#     389         )
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     292
#     293         with self._lock:
# --> 294             server_descriptions = self._select_servers_loop(
#     295                 selector, server_timeout, operation, operation_id, address
#     296             )
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     342                         failure=self._error_message(selector),
#     343                     )
# --> 344                 raise ServerSelectionTimeoutError(
#     345                     f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     346                 )
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 69563ff83095d4967aefbb62, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
#2. Retrieve and print all documents from the Orders collection.
db.orders.find()

# %%
#3. Count the total number of documents in the Orders collection.
db.orders.count_documents({})
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /tmp/ipython-input-264657525.py in <cell line: 0>()
#       1 #3. Count the total number of documents in the Orders collection.
# ----> 2 db.orders.count_documents({})
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in count_documents(self, filter, session, comment, **kwargs)
#    2161             return result["n"]
#    2162
# -> 2163         return self._retryable_non_cursor_read(_cmd, session, _Op.COUNT)
#    2164
#    2165     def _retryable_non_cursor_read(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in _retryable_non_cursor_read(self, func, session, operation)
#    2175         client = self._database.client
#    2176         with client._tmp_session(session) as s:
# -> 2177             return client._retryable_read(func, self._read_preference_for(s), s, operation)
#    2178
#    2179     def create_indexes(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2045             retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046         )
# -> 2047         return self._retry_internal(
#    2048             func,
#    2049             session,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    2012             retryable=retryable,
#    2013             operation_id=operation_id,
# -> 2014         ).run()
#    2015
#    2016     def _retryable_read(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in run(self)
#    2763             self._check_last_error(check_csot=True)
#    2764             try:
# -> 2765                 return self._read() if self._is_read else self._write()
#    2766             except ServerSelectionTimeoutError:
#    2767                 # The application may think the write was never attempted
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _read(self)
#    2908         :return: Output for func()'s call
#    2909         """
# -> 2910         self._server = self._get_server()
#    2911         assert self._read_pref is not None, "Read Preference required on read calls"
#    2912         with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _get_server(self)
#    2856         :return: Abstraction to connect to server
#    2857         """
# -> 2858         return self._client._select_server(
#    2859             self._server_selector,
#    2860             self._session,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831                     raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832             else:
# -> 1833                 server = topology.select_server(
#    1834                     server_selector,
#    1835                     operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     407     ) -> Server:
#     408         """Like select_servers, but choose a random server if several match."""
# --> 409         server = self._select_server(
#     410             selector,
#     411             operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     385         operation_id: Optional[int] = None,
#     386     ) -> Server:
# --> 387         servers = self.select_servers(
#     388             selector, operation, server_selection_timeout, address, operation_id
#     389         )
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     292
#     293         with self._lock:
# --> 294             server_descriptions = self._select_servers_loop(
#     295                 selector, server_timeout, operation, operation_id, address
#     296             )
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     342                         failure=self._error_message(selector),
#     343                     )
# --> 344                 raise ServerSelectionTimeoutError(
#     345                     f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     346                 )
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 69563e113095d4967aef9456, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
#4. Fetch all orders from the "West" region.
db.orders.find({ Region: "West" })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1226264742.py in <cell line: 0>()
#       1 #4. Fetch all orders from the "West" region.
# ----> 2 db.orders.find({ Region: "West" })
#
# NameError: name 'Region' is not defined

# %%
#5. Find orders where Sales is greater than 500.
db.orders.find({ Sales: { $gt: 500 } })
# Out:
#   File "/tmp/ipython-input-99469389.py", line 2
#     db.orders.find({ Sales: { $gt: 500 } })
#                               ^
# SyntaxError: invalid syntax

# %%
#6. Fetch the top 3 orders with the highest Profit.
db.orders.find().sort({ Profit: -1 }).limit(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-351280750.py in <cell line: 0>()
#       1 #6. Fetch the top 3 orders with the highest Profit.
# ----> 2 db.orders.find().sort({ Profit: -1 }).limit(3)
#
# NameError: name 'Profit' is not defined

# %%
#7. Update Ship Mode from "First Class" to "Premium Class".
db.orders.updateMany(
  { "Ship Mode": "First Class" },
  { $set: { "Ship Mode": "Premium Class" } }
)
# Out:
#   File "/tmp/ipython-input-1527137869.py", line 4
#     { $set: { "Ship Mode": "Premium Class" } }
#       ^
# SyntaxError: invalid syntax

# %%
#8. Delete all orders where Sales is less than 50.
db.orders.deleteMany({ Sales: { $lt: 50 } })
# Out:
#   File "/tmp/ipython-input-3825382460.py", line 2
#     db.orders.deleteMany({ Sales: { $lt: 50 } })
#                                     ^
# SyntaxError: invalid syntax

# %%
#9. Group orders by Region and calculate total sales per region.
db.orders.aggregate([
  { $group: { _id: "$Region", totalSales: { $sum: "$Sales" } } }
])
# Out:
#   File "/tmp/ipython-input-3279085458.py", line 3
#     { $group: { _id: "$Region", totalSales: { $sum: "$Sales" } } }
#       ^
# SyntaxError: invalid syntax

# %%
#10. Fetch all distinct values for Ship Mode.
db.orders.distinct("Ship Mode")
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /tmp/ipython-input-4097804907.py in <cell line: 0>()
#       1 #10. Fetch all distinct values for Ship Mode.
# ----> 2 db.orders.distinct("Ship Mode")
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in distinct(self, key, filter, session, comment, hint, **kwargs)
#    3220             )["values"]
#    3221
# -> 3222         return self._retryable_non_cursor_read(_cmd, session, operation=_Op.DISTINCT)
#    3223
#    3224     def _find_and_modify(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in _retryable_non_cursor_read(self, func, session, operation)
#    2175         client = self._database.client
#    2176         with client._tmp_session(session) as s:
# -> 2177             return client._retryable_read(func, self._read_preference_for(s), s, operation)
#    2178
#    2179     def create_indexes(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2045             retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2046         )
# -> 2047         return self._retry_internal(
#    2048             func,
#    2049             session,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    2012             retryable=retryable,
#    2013             operation_id=operation_id,
# -> 2014         ).run()
#    2015
#    2016     def _retryable_read(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in run(self)
#    2763             self._check_last_error(check_csot=True)
#    2764             try:
# -> 2765                 return self._read() if self._is_read else self._write()
#    2766             except ServerSelectionTimeoutError:
#    2767                 # The application may think the write was never attempted
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _read(self)
#    2908         :return: Output for func()'s call
#    2909         """
# -> 2910         self._server = self._get_server()
#    2911         assert self._read_pref is not None, "Read Preference required on read calls"
#    2912         with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _get_server(self)
#    2856         :return: Abstraction to connect to server
#    2857         """
# -> 2858         return self._client._select_server(
#    2859             self._server_selector,
#    2860             self._session,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1831                     raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1832             else:
# -> 1833                 server = topology.select_server(
#    1834                     server_selector,
#    1835                     operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     407     ) -> Server:
#     408         """Like select_servers, but choose a random server if several match."""
# --> 409         server = self._select_server(
#     410             selector,
#     411             operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     385         operation_id: Optional[int] = None,
#     386     ) -> Server:
# --> 387         servers = self.select_servers(
#     388             selector, operation, server_selection_timeout, address, operation_id
#     389         )
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     292
#     293         with self._lock:
# --> 294             server_descriptions = self._select_servers_loop(
#     295                 selector, server_timeout, operation, operation_id, address
#     296             )
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     342                         failure=self._error_message(selector),
#     343                     )
# --> 344                 raise ServerSelectionTimeoutError(
#     345                     f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     346                 )
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 69563e113095d4967aef9456, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
#11. Count the number of orders for each category.
db.orders.aggregate([
  { $group: { _id: "$Category", count: { $sum: 1 } } }
])
